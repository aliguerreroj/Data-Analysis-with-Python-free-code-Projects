# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
df = pd.read_csv('fcc-forum-pageviews.csv',index_col=0,parse_dates=True)
df
# Out:
#              value
# date
# 2016-05-09    1201
# 2016-05-10    2329
# 2016-05-11    1716
# 2016-05-12   10539
# 2016-05-13    6933
# ...            ...
# 2019-11-29  171584
# 2019-11-30  141161
# 2019-12-01  142918
# 2019-12-02  220144
# 2019-12-03  158549
#
# [1304 rows x 1 columns]

# %%
df.plot(figsize=(16,9))
# Out:
# <Axes: xlabel='date'>

# %%
df.loc["2016-11-01":"2016-12-15"].plot(y="value",figsize=(16,9))
# Out:
# <Axes: xlabel='date'>

# %%
df.loc["2016-11-01":"2016-11-15"]
# Out:
#              value
# date
# 2016-11-01   25856
# 2016-11-02   26565
# 2016-11-03   30183
# 2016-11-04   28981
# 2016-11-05   25849
# 2016-11-06   25287
# 2016-11-07   27790
# 2016-11-08   26744
# 2016-11-09   25489
# 2016-11-10  117906
# 2016-11-12   33775
# 2016-11-13   22762
# 2016-11-14   24449
# 2016-11-15   30817

# %%
percentil_inferior = df['value'].quantile(0.025)
percentil_superior = df['value'].quantile(0.975)
df = df[(df['value'] >= percentil_inferior) & (df['value'] <= percentil_superior)]
df.plot(figsize=(25,4))
# Out:
# <Axes: xlabel='date'>

# %%
plt.figure(figsize=(16, 6))
plt.title("Daily freeCodeCamp Forum Page Views 5/2016-12/2019")
plt.xlabel("Date")
plt.ylabel("Page Views")
plt.plot(df,color='red')

# %%
    plt.figure(figsize=(16, 6))
    

    fig, ax = plt.subplots(figsize=(10, 6))
     # Save image and return fig (don't change this part)
    ax.plot(df,color='red')

    plt.title("Daily freeCodeCamp Forum Page Views 5/2016-12/2019")
    plt.xlabel("Date")
    plt.ylabel("Page Views")

    fig.savefig('line_plot.png')

# %%
df.index = pd.to_datetime(df.index)

df['Year'] = df.index.year
df['Month'] = df.index.month_name()
promedio_mensual = df.groupby(['Year', 'Month'])['value'].mean().unstack()

meses_ordenados = ['January','February','March','April','May','June','July','August','September','October','November','December']
promedio_mensual= promedio_mensual[meses_ordenados]
promedio_mensual.index
# Out:
# Index([2016, 2017, 2018, 2019], dtype='int32', name='Year')

# %%
df['value']
# Out:
# 0         1201
# 1         2329
# 2         1716
# 3        10539
# 4         6933
#          ...
# 1299    171584
# 1300    141161
# 1301    142918
# 1302    220144
# 1303    158549
# Name: value, Length: 1304, dtype: int64

# %%
df = pd.read_csv('fcc-forum-pageviews.csv', index_col=0,parse_dates=['date'])

df['Year'] = df.index.year
df['Month'] = df.index.month_name()

# Calcular el promedio por año y mes
monthly_avg = df.groupby(['Year', 'Month'])['value'].mean().reset_index()

# Pivotar para facilitar la gráfica
data_pivot = monthly_avg.pivot(index='Year', columns='Month', values='value')

# Ordenar meses en el orden correcto
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
data_pivot = data_pivot[month_order]

# Graficar
data_pivot.plot(kind='bar', figsize=(12,8), colormap='tab20')
plt.title('Average Page Views per Month')
plt.xlabel('Years')
plt.ylabel('Average Page Views')
plt.legend(title='Months')
plt.grid(axis='y')
plt.show()

# %%
monthly_avg
# Out:
#     Year      Month          value
# 0   2016     August   31049.193548
# 1   2016   December   27832.419355
# 2   2016       July   23314.225806
# 3   2016       June   19124.366667
# 4   2016        May   11242.695652
# 5   2016   November   40448.633333
# 6   2016    October   27398.322581
# 7   2016  September   41476.866667
# 8   2017      April   30878.733333
# 9   2017     August   47712.451613
# 10  2017   December   48420.580645
# 11  2017   February   31113.071429
# 12  2017    January   32785.161290
# 13  2017       July   65806.838710
# 14  2017       June   43577.500000
# 15  2017      March   29369.096774
# 16  2017        May   34244.290323
# 17  2017   November   57701.566667
# 18  2017    October   47438.709677
# 19  2017  September   47376.800000
# 20  2018      April   62350.833333
# 21  2018     August   62831.612903
# 22  2018   December   80047.483871
# 23  2018   February   65679.000000
# 24  2018    January   58580.096774
# 25  2018       July   63591.064516
# ...

# %%
data_pivot
# Out:
# Month        January       February         March         April           May  \
# Year
# 2016             NaN            NaN           NaN           NaN  11242.695652
# 2017    32785.161290   31113.071429  29369.096774  30878.733333  34244.290323
# 2018    58580.096774   65679.000000  62693.774194  62350.833333  56562.870968
# 2019   102056.516129  105968.357143  91214.483871  89368.433333  91439.903226
#
# Month           June           July         August     September  \
# Year
# 2016    19124.366667   23314.225806   31049.193548  41476.866667
# 2017    43577.500000   65806.838710   47712.451613  47376.800000
# 2018    70117.000000   63591.064516   62831.612903  65941.733333
# 2019   162402.600000  100804.451613  117991.032258  97268.833333
#
# Month        October       November       December
# Year
# 2016    27398.322581   40448.633333   27832.419355
# 2017    47438.709677   57701.566667   48420.580645
# 2018   112592.000000   78688.333333   80047.483871
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Cargar los datos (simulando que ya tienes un DataFrame llamado df)
df = pd.read_csv('fcc-forum-pageviews.csv', index_col=0,parse_dates=['date'])

# 2. Crear nuevas columnas para Año y Mes
df["Year"] = df.index.year
df["Month"] = df.index.month

# 3. Agrupar los datos por Año y Mes, calculando el promedio de 'value'
monthly_avg = df.groupby(["Year", "Month"])["value"].mean().unstack()

# 4. Crear la gráfica
plt.figure(figsize=(10, 6))

# Configurar colores con Seaborn para una mejor visualización
colors = sns.color_palette("tab10", 12)

# 5. Graficar los datos como barras agrupadas
monthly_avg.plot(kind="bar", figsize=(12, 7), width=0.8, color=colors)

# # 6. Configurar etiquetas y título
plt.xlabel("Years", fontsize=12)
plt.ylabel("Average Page Views", fontsize=12)
plt.title("Monthly Average Page Views Over the Years", fontsize=14)
plt.legend(title="Months", labels=[
    "January", "February", "March", "April", "May", "June",
    "July", "August", "September", "October", "November", "December"
], fontsize=10)
plt.xticks(rotation=45)  # Rotar etiquetas del eje X

# 7. Mostrar la gráfica
plt.show()

# %%
monthly_avg
# Out:
# Month             1              2             3             4             5   \
# Year
# 2016             NaN            NaN           NaN           NaN  11242.695652
# 2017    32785.161290   31113.071429  29369.096774  30878.733333  34244.290323
# 2018    58580.096774   65679.000000  62693.774194  62350.833333  56562.870968
# 2019   102056.516129  105968.357143  91214.483871  89368.433333  91439.903226
#
# Month             6              7              8             9   \
# Year
# 2016    19124.366667   23314.225806   31049.193548  41476.866667
# 2017    43577.500000   65806.838710   47712.451613  47376.800000
# 2018    70117.000000   63591.064516   62831.612903  65941.733333
# 2019   162402.600000  100804.451613  117991.032258  97268.833333
#
# Month             10             11             12
# Year
# 2016    27398.322581   40448.633333   27832.419355
# 2017    47438.709677   57701.566667   48420.580645
# 2018   112592.000000   78688.333333   80047.483871
# ...

# %%
def draw_bar_plot():
    # Cargar datos
    df = pd.read_csv('fcc-forum-pageviews.csv', index_col=0, parse_dates=['date'])

    # Extraer año y mes
    df['Year'] = df.index.year
    df['Month'] = df.index.month_name()

    # Calcular el promedio por año y mes
    monthly_avg = df.groupby(['Year', 'Month'])['value'].mean().reset_index()

    # Pivotar para estructurar los datos para la gráfica
    data_pivot = monthly_avg.pivot(index='Year', columns='Month', values='value')

    # Ordenar los meses en el orden correcto
    month_order = ['January', 'February', 'March', 'April', 'May', 'June', 
                   'July', 'August', 'September', 'October', 'November', 'December']
    data_pivot = data_pivot[month_order]

    # Configurar colores con Seaborn
    colors = sns.color_palette("tab10", 12)

    # Crear figura y ejes
    plt.close('all') # Cerrar figuras previas
    fig, ax = plt.subplots(figsize=(12, 8))

    # Graficar
    data_pivot.plot(kind='bar', ax=ax, color=colors)

    # Personalizar
    ax.set_title('Average Page Views per Month', fontsize=16)
    ax.set_xlabel('Years', fontsize=12)
    ax.set_ylabel('Average Page Views', fontsize=12)
    ax.legend(title='Months', fontsize=10)
    ax.grid(axis='y')

    # Guardar la imagen y retornar la figura
    fig.savefig('bar_plot.png')
    return fig
draw_bar_plot()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('fcc-forum-pageviews.csv', index_col=0, parse_dates=['date'])

df = df[(df['value'] >= df['value'].quantile(0.025)) & 
        (df['value'] <= df['value'].quantile(0.975))]

df.loc[:, 'Year'] = df.index.year
df.loc[:, 'Month'] = df.index.strftime('%b')

def draw_box_plot():
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    sns.boxplot(x='Year', y='value', hue='Year', data=df, ax=axes[0], palette='Set2', legend=False)
    axes[0].set_title('Year-wise Box Plot (Trend)')
    axes[0].set_xlabel('Year')
    axes[0].set_ylabel('Page Views')
    

    
    month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun','Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
    sns.boxplot(x='Month', y='value', hue='Month', data=df, ax=axes[1], palette='Set3', order=month_order, legend=False)
    axes[1].set_title('Month-wise Box Plot (Seasonality)')
    axes[1].set_xlabel('Year')
    axes[1].set_ylabel('Page Views')


    # Ajustar diseño
    plt.tight_layout()

    # Guardar imagen
    fig.savefig('box_plot.png')
    return fig
    
draw_box_plot()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar datos
df = pd.read_csv('fcc-forum-pageviews.csv', parse_dates=['date'], index_col='date')

# Limpiar datos (opcional, ajustar si es necesario)
df = df[(df['value'] >= df['value'].quantile(0.025)) & (df['value'] <= df['value'].quantile(0.975))]

# Preparar datos para box plots
df_box = df.copy()
df_box.reset_index(inplace=True)
df_box['Year'] = df_box['date'].dt.year
df_box['Month'] = df_box['date'].dt.strftime('%b')

# Ordenar los meses para que inicien en Enero
month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Crear figura y ejes
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Gráfico 1: Diagrama de caja por año
sns.boxplot(x='Year', y='value', hue='Year', data=df_box, ax=axes[0], palette='Set2', legend=False)
axs[0].set_title('Diagrama de caja anual (Tendencia)')
axs[0].set_xlabel('Año')
axs[0].set_ylabel('Visitas a la página')

# Gráfico 2: Diagrama de caja por mes
sns.boxplot(x='Month', y='value', hue='Month', data=df_box, ax=axes[1], palette='Set3', order=month_order, legend=False)
axs[1].set_title('Diagrama de caja mensual (Estacionalidad)')
axs[1].set_xlabel('Mes')
axs[1].set_ylabel('Visitas a la página')

# Ajustes finales
plt.tight_layout()

# Guardar la figura (como se solicita)
fig.savefig('box_plot.png')

# %%
def draw_box_plot2():

    df = pd.read_csv('fcc-forum-pageviews.csv', parse_dates=['date'], index_col='date')

    # Limpiar datos (opcional, ajustar si es necesario)
    df = df[(df['value'] >= df['value'].quantile(0.025)) & (df['value'] <= df['value'].quantile(0.975))]

    # Preparar datos para box plots
    b = df.copy()
    df_box.reset_index(inplace=True)
    df_box['Year'] = df_box['date'].dt.year
    df_box['Month'] = df_box['date'].dt.strftime('%b')

    # Ordenar los meses para que inicien en Enero
    month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

    # Crear figura y ejes
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # Gráfico 1: Diagrama de caja por año
    sns.boxplot(x='Year', y='value', hue='Year', data=df_box, ax=axes[0], palette='Set2', legend=False)
    axes[0].set_title('Diagrama de caja anual (Tendencia)')
    axes[0].set_xlabel('Año')
    axes[0].set_ylabel('Visitas a la página')

    # Gráfico 2: Diagrama de caja por mes
    sns.boxplot(x='Month', y='value', hue='Month', data=df_box, ax=axes[1], palette='Set3', order=month_order, legend=False)
    axes[1].set_title('Diagrama de caja mensual (Estacionalidad)')
    axes[1].set_xlabel('Mes')
    axes[1].set_ylabel('Visitas a la página')

    # Ajustes finales
    plt.tight_layout()

    # Guardar la figura (como se solicita)
    fig.savefig('box_plot2.png')

    return fig

draw_box_plot2()

# %%
def draw_line_plot():

    df = pd.read_csv('fcc-forum-pageviews.csv',index_col=0,parse_dates=True)

    # Clean data
    percentil_inferior = df['value'].quantile(0.025)
    percentil_superior = df['value'].quantile(0.975)
    df = df[(df['value'] >= percentil_inferior) & (df['value'] <= percentil_superior)]
    # Draw line plot
    plt.figure(figsize=(16, 6))
    

    fig, ax = plt.subplots(figsize=(10, 6))
    
    ax.plot(df,color='red')

    plt.title("Daily freeCodeCamp Forum Page Views 5/2016-12/2019")
    plt.xlabel("Date")
    plt.ylabel("Page Views")
    # Save image and return fig (don't change this part)
    fig.savefig('line_plot.png')
    return fig
draw_line_plot()

# %%
def draw_bar_plot():
    # Copy and modify data for monthly bar plot
    df = pd.read_csv('fcc-forum-pageviews.csv',index_col=0,parse_dates=True)

    # Clean data
    percentil_inferior = df['value'].quantile(0.025)
    percentil_superior = df['value'].quantile(0.975)
    df = df[(df['value'] >= percentil_inferior) & (df['value'] <= percentil_superior)]

    # Extraer año y mes
    df['Year'] = df.index.year
    df['Month'] = df.index.month_name()

    # Calcular el promedio por año y mes
    monthly_avg = df.groupby(['Year', 'Month'])['value'].mean().reset_index()

    # Pivotar para estructurar los datos para la gráfica
    data_pivot = monthly_avg.pivot(index='Year', columns='Month', values='value')

    # Ordenar los meses en el orden correcto
    month_order = ['January', 'February', 'March', 'April', 'May', 'June', 
                   'July', 'August', 'September', 'October', 'November', 'December']
    data_pivot = data_pivot[month_order]

    # Configurar colores con Seaborn
    colors = sns.color_palette("tab10", 12)

    # Crear figura y ejes
    plt.close('all') # Cerrar figuras previas
    fig, ax = plt.subplots(figsize=(12, 8))

    # Graficar
    data_pivot.plot(kind='bar', ax=ax, color=colors)

    # Personalizar
    ax.set_title('Average Page Views per Month', fontsize=16)
    ax.set_xlabel('Years', fontsize=12)
    ax.set_ylabel('Average Page Views', fontsize=12)
    ax.legend(title='Months', fontsize=10)
    ax.grid(axis='y')

    # Guardar la imagen y retornar la figura
    fig.savefig('bar_plot.png')
    return fig

draw_bar_plot()

# %%
    df = pd.read_csv('fcc-forum-pageviews.csv',index_col=0,parse_dates=True)

    # Clean data
    percentil_inferior = df['value'].quantile(0.025)
    percentil_superior = df['value'].quantile(0.975)
    df = df[(df['value'] >= percentil_inferior) & (df['value'] <= percentil_superior)]

    # Extraer año y mes
    df['Year'] = df.index.year
    df['Month'] = df.index.month_name()

    # Calcular el promedio por año y mes
    monthly_avg = df.groupby(['Year', 'Month'])['value'].mean().reset_index()

    # Pivotar para estructurar los datos para la gráfica
    data_pivot = monthly_avg.pivot(index='Year', columns='Month', values='value')

    # Ordenar los meses en el orden correcto
    month_order = ['January', 'February', 'March', 'April', 'May', 'June', 
                   'July', 'August', 'September', 'October', 'November', 'December']
    
    data_pivot[month_order]
# Out:
# Month        January       February         March         April           May  \
# Year
# 2016             NaN            NaN           NaN           NaN  19432.400000
# 2017    32785.161290   31113.071429  29369.096774  30878.733333  34244.290323
# 2018    58580.096774   65679.000000  62693.774194  62350.833333  56562.870968
# 2019   102056.516129  105968.357143  91214.483871  89368.433333  91439.903226
#
# Month          June          July         August     September        October  \
# Year
# 2016   21875.105263  24109.678571   31049.193548  41476.866667   27398.322581
# 2017   43577.500000  65806.838710   47712.451613  47376.800000   47438.709677
# 2018   70117.000000  63591.064516   62831.612903  65941.733333  111378.142857
# 2019   90435.642857  97236.566667  102717.310345  97268.833333  122802.272727
#
# Month       November       December
# Year
# 2016    40448.633333   27832.419355
# 2017    57701.566667   48420.580645
# 2018    78688.333333   80047.483871
# ...
