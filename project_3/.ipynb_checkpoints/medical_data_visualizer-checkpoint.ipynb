# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
df= pd.read_csv('medical_examination.csv',index_col="id")
df
# Out:
#          age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# id
# 0      18393    2     168    62.0    110     80            1     1      0
# 1      20228    1     156    85.0    140     90            3     1      0
# 2      18857    1     165    64.0    130     70            3     1      0
# 3      17623    2     169    82.0    150    100            1     1      0
# 4      17474    1     156    56.0    100     60            1     1      0
# ...      ...  ...     ...     ...    ...    ...          ...   ...    ...
# 99993  19240    2     168    76.0    120     80            1     1      1
# 99995  22601    1     158   126.0    140     90            2     2      0
# 99996  19066    2     183   105.0    180     90            3     1      0
# 99998  22431    1     163    72.0    135     80            1     2      0
# 99999  20540    1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# id
# 0         0       1       0
# ...

# %%
Normalice los datos estableciendo que 0 siempre sea bueno y 1 siempre malo. Si el valor de colesterol o glucosa es 1, establezca el valor en 0. 
Si el valor es mayor que 1, establezca el valor en 1.

# %%
# Si colesterol es 1, se convierte a 0. Si es mayor que 1, se convierte a 1.
df.loc[df['cholesterol'] == 1, 'cholesterol'] = 0
df.loc[df['cholesterol'] > 1, 'cholesterol'] = 1

# Si glucosa es 1, se convierte a 0. Si es mayor que 1, se convierte a 1.
df.loc[df['gluc'] == 1, 'gluc'] = 0
df.loc[df['gluc'] > 1, 'gluc'] = 1
df
# Out:
#          age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# id
# 0      18393    2     168    62.0    110     80            0     0      0
# 1      20228    1     156    85.0    140     90            1     0      0
# 2      18857    1     165    64.0    130     70            1     0      0
# 3      17623    2     169    82.0    150    100            0     0      0
# 4      17474    1     156    56.0    100     60            0     0      0
# ...      ...  ...     ...     ...    ...    ...          ...   ...    ...
# 99993  19240    2     168    76.0    120     80            0     0      1
# 99995  22601    1     158   126.0    140     90            1     1      0
# 99996  19066    2     183   105.0    180     90            1     0      0
# 99998  22431    1     163    72.0    135     80            0     1      0
# 99999  20540    1     170    72.0    120     80            1     0      0
#
#        alco  active  cardio
# id
# 0         0       1       0
# ...

# %%
df[['cholesterol', 'gluc']].value_counts()
# Out:
# cholesterol  gluc
# 0            0       48672
# 1            0       10807
#              1        6808
# 0            1        3713
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# age              int64
# sex              int64
# height           int64
# weight         float64
# ap_hi            int64
# ap_lo            int64
# cholesterol      int64
# gluc             int64
# smoke            int64
# alco             int64
# active           int64
# cardio           int64
# dtype: object

# %%
df['height'] = (df['height'] / 100)
df['overweight'] = df['weight']/(df['height']) ** 2
df['overweight'] = np.where(df['overweight'] <= 25 ,0, 1)

df
# Out:
#          age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# id
# 0      18393    2    1.68    62.0    110     80            0     0      0
# 1      20228    1    1.56    85.0    140     90            1     0      0
# 2      18857    1    1.65    64.0    130     70            1     0      0
# 3      17623    2    1.69    82.0    150    100            0     0      0
# 4      17474    1    1.56    56.0    100     60            0     0      0
# ...      ...  ...     ...     ...    ...    ...          ...   ...    ...
# 99993  19240    2    1.68    76.0    120     80            0     0      1
# 99995  22601    1    1.58   126.0    140     90            1     1      0
# 99996  19066    2    1.83   105.0    180     90            1     0      0
# 99998  22431    1    1.63    72.0    135     80            0     1      0
# 99999  20540    1    1.70    72.0    120     80            1     0      0
#
#        alco  active  cardio  overweight
# id
# ...

# %%
Cree un DataFrame para el gráfico cat usando pd.melt con los valores de colesterol, glucosa, tabaquismo, alcohol, actividad física y sobrepeso en la variable df_cat.
Agrupe y reformatee los datos en df_cat para dividirlos por cardio. Muestre los recuentos de cada característica. 
Deberá cambiar el nombre de una de las columnas para que el gráfico cat funcione correctamente.

# %%
df_cat  = pd.melt(df, id_vars=['cardio'], value_vars=['cholesterol', 'gluc', 'alco','overweight','smoke','active'], 
                    var_name='variable', value_name='value')
df_cat
# Out:
#         cardio     variable  value
# 0            0  cholesterol      0
# 1            1  cholesterol      1
# 2            1  cholesterol      1
# 3            1  cholesterol      0
# 4            0  cholesterol      0
# ...        ...          ...    ...
# 419995       0       active      1
# 419996       1       active      1
# 419997       1       active      0
# 419998       1       active      0
# 419999       0       active      1
#
# [420000 rows x 3 columns]

# %%
# df_cat_grouped 
df_cat= df_cat.groupby(['cardio','variable','value']).size().reset_index(name='total')
df_cat
# Out:
#     cardio     variable  value  total
# 0        0       active      0   6378
# 1        0       active      1  28643
# 2        0         alco      0  33080
# 3        0         alco      1   1941
# 4        0  cholesterol      0  29330
# 5        0  cholesterol      1   5691
# 6        0         gluc      0  30894
# 7        0         gluc      1   4127
# 8        0   overweight      0  15915
# 9        0   overweight      1  19106
# 10       0        smoke      0  31781
# 11       0        smoke      1   3240
# 12       1       active      0   7361
# 13       1       active      1  27618
# 14       1         alco      0  33156
# 15       1         alco      1   1823
# 16       1  cholesterol      0  23055
# 17       1  cholesterol      1  11924
# 18       1         gluc      0  28585
# 19       1         gluc      1   6394
# 20       1   overweight      0  10539
# 21       1   overweight      1  24440
# 22       1        smoke      0  32050
# 23       1        smoke      1   2929

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

sns.catplot(
    data=df_cat,
    kind="bar",
    x="variable",
    y="total",
    hue="value",
    col="cardio",
    height=6,
    aspect=1
)

# Ajustar etiquetas y títulos

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Paso 1: Importar los datos
df = pd.read_csv('medical_examination.csv')

# Paso 2:  Normalizar colesterol y gl
df.loc[df['cholesterol'] == 1, 'cholesterol'] = 0
df.loc[df['cholesterol'] > 1, 'cholesterol'] = 1

# Si glucosa es 1, se convierte a 0. Si es mayor que 1, se convierte a 1.
df.loc[df['gluc'] == 1, 'gluc'] = 0
df.loc[df['gluc'] > 1, 'gluc'] = 1

# Paso 3:  Agregar columna de sobrepeso
df['height'] = (df['height'] / 100)
df['overweight'] = df['weight']/(df['height']) ** 2
df['overweight'] = np.where(df['overweight'] <= 25 ,0, 1)

# Paso 4: Crear DataFrame para el gráfico categórico usando pd.melt
df_cat  = pd.melt(df, id_vars=['cardio'], 
                value_vars=['cholesterol', 'gluc', 'alco','overweight','smoke','active'], 
                var_name='variable', value_name='value'
                )

# Paso 5: Agrupar y reformatear los datos
df_cat = df_cat.groupby(['cardio','variable','value']).size().reset_index(name='total')

# Paso 6: Renombrar columna para el gráfico
df_cat = df_cat.rename(columns={'value': 'status'})

# Paso 7: Dibujar el gráfico categórico
def draw_cat_plot():
    g = sns.catplot(
        data=df_cat,
        x='variable',
        y='total',
        hue='status',
        col='cardio',
        kind='bar',
        height=6,
        aspect=1
    )
    g.set_axis_labels('Variable', 'Total')
    plt.show()

draw_cat_plot()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Paso 1: Importar los datos
df = pd.read_csv('medical_examination.csv',index_col="id")

# Paso 2:  Normalizar colesterol y gl
df.loc[df['cholesterol'] == 1, 'cholesterol'] = 0
df.loc[df['cholesterol'] > 1, 'cholesterol'] = 1

# Si glucosa es 1, se convierte a 0. Si es mayor que 1, se convierte a 1.
df.loc[df['gluc'] == 1, 'gluc'] = 0
df.loc[df['gluc'] > 1, 'gluc'] = 1

# Paso 3:  Agregar columna de sobrepeso
df['height'] = (df['height'] / 100)
df['overweight'] = df['weight']/(df['height']) ** 2
df['overweight'] = np.where(df['overweight'] <= 25 ,0, 1)

# Paso 4: Crear DataFrame para el gráfico categórico usando pd.melt
df_cat  = pd.melt(df, id_vars=['cardio'], 
                value_vars=['cholesterol', 'gluc', 'alco','overweight','smoke','active'], 
                var_name='variable', value_name='value'
                )

# Paso 5: Agrupar y reformatear los datos
df_cat = df_cat.groupby(['cardio','variable','value']).size().reset_index(name='total')

# Paso 6: Renombrar columna para el gráfico
df_cat = df_cat.rename(columns={'value': 'status'})
    

# Paso 7: Dibujar el gráfico categórico
def draw_cat_plot():
    fig = sns.catplot(x='variable', y='total', hue='status', col='cardio', data=df_cat, kind='bar')
    
    # Ajustar el diseño
    fig.set_axis_labels('variable', 'total')
    fig.set_titles('cardio = {col_name}')
    fig.legend.set_title('value')
    
    # Guardar la figura
    fig.savefig('catplot.png')
    
    # Retornar la figura
    return fig

draw_cat_plot()

# %%
Dibuje el mapa de calor con la función draw_heat_map.

Limpie los datos de la variable df_heat filtrando los siguientes segmentos de pacientes que representan datos incorrectos:
La presión diastólica es mayor que la sistólica (Mantenga los datos correctos con (df['ap_lo'] <= df['ap_hi']))
La estatura es menor que el percentil 2,5 (Mantenga los datos correctos con (df['height'] >= df['height'].quantile(0.025)))
La estatura es mayor que el percentil 97,5
El peso es menor que el percentil 2,5
El peso es mayor que el percentil 97,5
Calcule la matriz de correlación y almacénela en la variable corr.
Genere una máscara para el triángulo superior y almacénela en la variable mask.
Configure la figura de matplotlib. Grafique la matriz de correlación utilizando el método proporcionado por la biblioteca seaborn import: sns.heatmap().
No modifique las dos líneas siguientes.

# %%
df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2    1.68    62.0    110     80            0     0
# 1          1  20228    1    1.56    85.0    140     90            1     0
# 2          2  18857    1    1.65    64.0    130     70            1     0
# 3          3  17623    2    1.69    82.0    150    100            0     0
# 4          4  17474    1    1.56    56.0    100     60            0     0
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2    1.68    76.0    120     80            0     0
# 69996  99995  22601    1    1.58   126.0    140     90            1     1
# 69997  99996  19066    2    1.83   105.0    180     90            1     0
# 69998  99998  22431    1    1.63    72.0    135     80            0     1
# 69999  99999  20540    1    1.70    72.0    120     80            1     0
#
#        smoke  alco  active  cardio  overweight
# ...

# %%
df_heat= df.copy()
df_heat= df_heat[df_heat['ap_lo'] <= df_heat['ap_hi']]
df_heat=df_heat[df_heat['height'] >= df_heat['height'].quantile(0.025)]
df_heat=df_heat[df_heat['height'] <= df_heat['height'].quantile(0.975)]
df_heat=df_heat[df_heat['weight'] >= df_heat['weight'].quantile(0.025)]
df_heat=df_heat[df_heat['weight'] <= df_heat['weight'].quantile(0.975)]
df_heat
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2    1.68    62.0    110     80            0     0
# 1          1  20228    1    1.56    85.0    140     90            1     0
# 2          2  18857    1    1.65    64.0    130     70            1     0
# 3          3  17623    2    1.69    82.0    150    100            0     0
# 4          4  17474    1    1.56    56.0    100     60            0     0
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69993  99991  19699    1    1.72    70.0    130     90            0     0
# 69994  99992  21074    1    1.65    80.0    150     80            0     0
# 69995  99993  19240    2    1.68    76.0    120     80            0     0
# 69998  99998  22431    1    1.63    72.0    135     80            0     1
# 69999  99999  20540    1    1.70    72.0    120     80            1     0
#
#        smoke  alco  active  cardio  overweight
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calcular la matriz de correlación
corr = df_heat.corr()

# Configurar la figura
plt.figure(figsize=(10, 8))
# Crear una máscara para la parte superior
mask = np.triu(np.ones_like(corr, dtype=bool))
# Crear el mapa de calor con sns.heatmap()

sns.heatmap(corr,mask=mask,annot=True, cmap="RdBu_r", fmt='.1f', linewidths=0.5)

# Agregar título
plt.title('Mapa de Calor de Correlación')
# Out:
# Text(0.5, 1.0, 'Mapa de Calor de Correlación')

# %%
def draw_heat_map():
    # 11
    df_heat= df.copy()
    df_heat= df_heat[df_heat['ap_lo'] <= df_heat['ap_hi']]
    df_heat=df_heat[df_heat['height'] >= df_heat['height'].quantile(0.025)]
    df_heat=df_heat[df_heat['height'] <= df_heat['height'].quantile(0.975)]
    df_heat=df_heat[df_heat['weight'] >= df_heat['weight'].quantile(0.025)]
    df_heat=df_heat[df_heat['weight'] <= df_heat['weight'].quantile(0.975)]
    
    # 12
    corr = df_heat.corr()


    # 13
    plt.figure(figsize=(10, 8))
    # Crear una máscara para la parte superior
    mask = np.triu(np.ones_like(corr, dtype=bool))
    # Crear el mapa de calor con sns.heatmap()
    plt.figure(figsize=(12, 10))
    sns.heatmap(corr,mask=mask,annot=True, cmap="RdBu_r", fmt='.1f', linewidths=0.5)

    # Agregar título
    plt.title('Correlation Heat Map')
    # plt.show()


    fig = plt.gcf()

    # 16
    fig.savefig('heatmap.png')
    return fig
draw_heat_map()
